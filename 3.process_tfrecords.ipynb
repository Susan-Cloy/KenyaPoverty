# %%
# %load_ext autoreload
# %autoreload 2

from __future__ import annotations

from collections.abc import Iterable
from glob import glob
from pprint import pprint
import os
from typing import Optional

import numpy as np
import pandas as pd
import tensorflow as tf
from tqdm.auto import tqdm

#import cartopy.crs as ccrs
#import cartopy.feature as cfeature
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
DHS_FOLDER = 'data/ke_dhs_tfrecords_raw'

TFRECORD_PATH_TEMPLATE = 'data/ke_dhs_tfrecords_raw/kenya_{year}.tfrecord.gz'

# %% [markdown]
# # Inspecting a single record in the TFRecord file

# %%
def get_feature_types(tfrecord_path):
    '''Gets the types and shapes of each feature in a feature_map.
    Args
    - tfrecord_path: str, path to a TFRecord file with GZIP compression
    Returns:
    - feature_types: dict, maps feature names (str) to tuple of (ft_type, ft_shape)
    '''
    options = tf.io.TFRecordOptions(compression_type = 'GZIP')
    iterator = tf.compat.v1.io.tf_record_iterator(tfrecord_path, options=options)

    # get the first Example stored in the TFRecords file
    record_str = next(iterator)
    example = tf.train.Example.FromString(record_str) 
    feature_map = example.features.feature  # get Features message within the Example

    # use the WhichOneof() method on messages with `oneof` fields to determine the type of the field
    feature_types = {}
    for name in feature_map.keys():
        ft_type = feature_map[name].WhichOneof('kind')
        ft_shape = np.array(feature_map[name].__getattribute__(ft_type).value).shape
        feature_types[name] = (ft_type, ft_shape)
        
    return feature_types

# %%
tfrecord_path = TFRECORD_PATH_TEMPLATE.format(year=2014)
feature_types = get_feature_types(tfrecord_path)
print(f'TFRecord path: {tfrecord_path}')
print('Features and types:')
pprint(feature_types)
# Out:
# TFRecord path: data/ke_dhs_tfrecords_raw/kenya_2014.tfrecord.gz
# Features and types:
# {'BLUE': ('float_list', (65025,)),
#  'GREEN': ('float_list', (65025,)),
#  'LAT': ('float_list', (65025,)),
#  'LON': ('float_list', (65025,)),
#  'NIGHTLIGHTS': ('float_list', (65025,)),
#  'NIR': ('float_list', (65025,)),
#  'RED': ('float_list', (65025,)),
#  'SWIR1': ('float_list', (65025,)),
#  'SWIR2': ('float_list', (65025,)),
#  'TEMP1': ('float_list', (65025,)),
#  'country': ('bytes_list', (1,)),
#  'households': ('float_list', (1,)),
#  'lat': ('float_list', (1,)),
#  'lon': ('float_list', (1,)),
#  'system:index': ('bytes_list', (1,)),
#  'urban_rural': ('float_list', (1,)),
#  'wealthpooled': ('float_list', (1,)),
#  'year': ('float_list', (1,))}

# %% [markdown]
# # Cross checking TFrecord Files against Survey Data Files

# %%
def split_survey(survey_path, out_dir, year):   
    '''
    Args
    - survey_path: str, path to complete survey CSV file
    - out_dir: str, path to output directory
    '''
    os.makedirs(out_dir, exist_ok=True)
    data = pd.read_csv(survey_path, float_precision='high')
    data = data.loc[data.year == year].drop(columns = ['GID_1', 'GID_2'])
    
    survey_out_name = f'kenya_{year}.csv'
    survey_out_path = os.path.join(out_dir, survey_out_name)
        
    # save CSV: pandas uses float64 which maintains enough precision for all of our numbers
    data.to_csv(survey_out_path, index=False)

# %%
survey_path = 'data/ke_dhs_clusters.csv'
out_dir = 'data/ke_dhs_surveys'
split_survey(survey_path, out_dir, 2014)
split_survey(survey_path, out_dir, 2015)

# %%
# checks that the fields in the TFRecords match the original CSV files.

REQUIRED_BANDS = ['BLUE', 'GREEN', 'LAT', 'LON', 'NIGHTLIGHTS', 'NIR', 'RED', 'SWIR1', 'SWIR2', 'TEMP1']

def crosscheck_records(csv_path, tfrecord_path):   
    '''crosschecks individual TFRecord files (for a given country-year survey). 
    1) verifies that it contains the required bands
    2) checks whether the other features match values from the survey CSV

    Args
    - csv_path: path to csv file containing survey data
    - tfrecord_paths: path to exported TFRecords file
    - df: pd.DataFrame, index is sequential and starts at 0
    '''
    df = pd.read_csv(csv_path, float_precision='high', index_col=False)
    df = df.drop(columns=['Unnamed: 0'])

    for col in df.columns:
        if df[col].dtype == np.float64:
            df[col] = df[col].astype(np.float32)
        elif df[col].dtype == object: 
            df[col] = df[col].astype(bytes)

    i = 0
    progbar = tqdm(total=len(df))
    
    options = tf.io.TFRecordOptions(compression_type = 'GZIP')
    iterator = tf.compat.v1.io.tf_record_iterator(tfrecord_path, options=options)

    for record_str in iterator:
        example = tf.train.Example.FromString(record_str)
        feature_map = example.features.feature

        for band in REQUIRED_BANDS:
            assert band in feature_map, f'Band "{band}" not in record {i} of {tfrecord_path}'

        csv_feats = df.loc[i, :].to_dict()       
        for col, val in csv_feats.items():
            ft_type = feature_map[col].WhichOneof('kind')
            ex_val = feature_map[col].__getattribute__(ft_type).value[0] 
            if val != ex_val:
                print(f'Expected {col}={val}, but found {col}={ex_val} instead') 
                  
            i += 1
            progbar.update(1)
    progbar.close()

# %%
crosscheck_records(csv_path='data/ke_dhs_surveys/kenya_2014.csv', tfrecord_path=TFRECORD_PATH_TEMPLATE.format(year=2014))
# Out:
#   0%|          | 0/1585 [00:00<?, ?it/s]
# Expected lat=-1.312427043914795, but found lat=-1.2787810564041138 instead
# Expected lon=36.78540802001953, but found lon=36.75844192504883 instead
# Expected wealthpooled=0.6667720079421997, but found wealthpooled=0.2383285015821457 instead
# Expected households=23, but found households=22.0 instead
# Expected lat=-1.254804015159607, but found lat=-1.2796460390090942 instead
# Expected lon=36.91013717651367, but found lon=36.74592971801758 instead
# Expected wealthpooled=1.2472656965255737, but found wealthpooled=1.0458334684371948 instead
# Expected households=19, but found households=25.0 instead
# Expected lat=-1.2795250415802002, but found lat=-1.2803800106048584 instead
# Expected lon=36.893592834472656, but found lon=36.69709014892578 instead
# Expected wealthpooled=1.137634515762329, but found wealthpooled=0.8064674735069275 instead
# Expected households=21, but found households=20.0 instead
# Expected lat=-1.2842650413513184, but found lat=-1.272063970565796 instead
# Expected lon=36.886566162109375, but found lon=36.743125915527344 instead
# Expected wealthpooled=1.4598958492279053, but found wealthpooled=0.735924243927002 instead
# Expected households=19, but found households=21.0 instead
# Expected lat=-1.3166919946670532, but found lat=-1.2630059719085693 instead
# Expected lon=36.872962951660156, but found lon=36.71059036254883 instead
# Expected wealthpooled=0.9640756249427795, but found wealthpooled=1.3266938924789429 instead
# Expected households=23, but found households=24.0 instead
# Expected lat=-1.1892529726028442, but found lat=-1.3415460586547852 instead
# Expected lon=36.905784606933594, but found lon=36.69718933105469 instead
# Expected wealthpooled=1.0994489192962646, but found wealthpooled=1.6741071939468384 instead
# Expected households=21, but found households=19.0 instead
# Expected lat=-1.2710609436035156, but found lat=-1.312427043914795 instead
# Expected lon=36.85728073120117, but found lon=36.78540802001953 instead
# Expected wealthpooled=0.8291522860527039, but found wealthpooled=0.6667720079421997 instead
# Expected households=24, but found households=23.0 instead
# Expected lat=-0.19877000153064728, but found lat=-1.318071961402893 instead
# Expected lon=36.52479553222656, but found lon=36.78468322753906 instead
# Expected wealthpooled=-0.07561872154474258, but found wealthpooled=0.611077606678009 instead
# Expected households=23, but found households=19.0 instead
# Expected lat=-0.14981800317764282, but found lat=-1.3151030540466309 instead
# Expected lon=36.37073516845703, but found lon=36.80952072143555 instead
# Expected wealthpooled=-0.11101780831813812, but found wealthpooled=0.756115198135376 instead
# Expected households=21, but found households=22.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.33160901069641113, but found lat=-1.3139630556106567 instead
# Expected lon=36.381187438964844, but found lon=36.81003189086914 instead
# Expected wealthpooled=0.10031423717737198, but found wealthpooled=1.8700670003890991 instead
# Expected households=21, but found households=18.0 instead
# Expected lat=-0.4046359956264496, but found lat=-1.31584894657135 instead
# Expected lon=36.51725769042969, but found lon=36.79335403442383 instead
# Expected wealthpooled=0.7118707299232483, but found wealthpooled=0.6909864544868469 instead
# Expected households=21, but found households=23.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.7397980093955994, but found lat=-1.2622050046920776 instead
# Expected lon=36.702415466308594, but found lon=36.89156723022461 instead
# Expected wealthpooled=0.12147808820009232, but found wealthpooled=1.1862339973449707 instead
# Expected households=21, but found households=22.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.19652000069618225, but found lat=-1.2554659843444824 instead
# Expected lon=37.030086517333984, but found lon=36.88676834106445 instead
# Expected wealthpooled=0.5291434526443481, but found wealthpooled=1.2695115804672241 instead
# Expected households=24, but found households=17.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.4954240024089813, but found lat=-1.254804015159607 instead
# Expected lon=37.12839126586914, but found lon=36.91013717651367 instead
# Expected wealthpooled=1.6169800758361816, but found wealthpooled=1.2472656965255737 instead
# Expected households=25, but found households=19.0 instead
# Expected lat=-0.3940429985523224, but found lat=-1.2456920146942139 instead
# Expected lon=37.08991622924805, but found lon=36.9012336730957 instead
# Expected wealthpooled=0.1436939686536789, but found wealthpooled=1.1971666812896729 instead
# Expected households=25, but found households=19.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.6360139846801758, but found lat=-1.3162750005722046 instead
# Expected lon=37.123260498046875, but found lon=36.918418884277344 instead
# Expected wealthpooled=-0.009335651993751526, but found wealthpooled=1.2639464139938354 instead
# Expected households=24, but found households=22.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.4229600131511688, but found lat=-1.2915199995040894 instead
# Expected lon=36.97764587402344, but found lon=36.93667984008789 instead
# Expected wealthpooled=1.380025029182434, but found wealthpooled=1.6868985891342163 instead
# Expected households=23, but found households=22.0 instead
# Expected lat=-0.7288450002670288, but found lat=-1.2626689672470093 instead
# Expected lon=37.3552131652832, but found lon=36.90116882324219 instead
# Expected wealthpooled=-0.3396872878074646, but found wealthpooled=0.9897681474685669 instead
# Expected households=25, but found households=17.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.6705340147018433, but found lat=-1.276155948638916 instead
# Expected lon=37.42005920410156, but found lon=36.921199798583984 instead
# Expected wealthpooled=-0.4975834786891937, but found wealthpooled=1.396193504333496 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.5098299980163574, but found lat=-1.2768549919128418 instead
# Expected lon=37.317291259765625, but found lon=36.91813278198242 instead
# Expected wealthpooled=0.7058649063110352, but found wealthpooled=1.260956883430481 instead
# Expected households=21, but found households=18.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.5748609900474548, but found lat=-1.2795250415802002 instead
# Expected lon=37.26616668701172, but found lon=36.893592834472656 instead
# Expected wealthpooled=0.9769809246063232, but found wealthpooled=1.137634515762329 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.43614399433135986, but found lat=-1.3152480125427246 instead
# Expected lon=37.341644287109375, but found lon=36.8807258605957 instead
# Expected wealthpooled=0.5705544948577881, but found wealthpooled=0.8280758261680603 instead
# Expected households=24, but found households=20.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.6808419823646545, but found lat=-1.3191900253295898 instead
# Expected lon=37.16929244995117, but found lon=36.88625717163086 instead
# Expected wealthpooled=-0.09462403506040573, but found wealthpooled=1.3633453845977783 instead
# Expected households=20, but found households=24.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.6580399870872498, but found lat=-1.3214099407196045 instead
# Expected lon=37.012107849121094, but found lon=36.89137649536133 instead
# Expected wealthpooled=-0.33521389961242676, but found wealthpooled=1.3503086566925049 instead
# Expected households=24, but found households=25.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.826304018497467, but found lat=-1.323410987854004 instead
# Expected lon=36.88203430175781, but found lon=36.8886604309082 instead
# Expected wealthpooled=0.19897305965423584, but found wealthpooled=1.2703558206558228 instead
# Expected households=25, but found households=22.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.7949659824371338, but found lat=-1.2429020404815674 instead
# Expected lon=36.90663528442383, but found lon=36.927059173583984 instead
# Expected wealthpooled=0.7698571085929871, but found wealthpooled=0.4271266460418701 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-1.0343929529190063, but found lat=-1.2850940227508545 instead
# Expected lon=37.36174011230469, but found lon=36.90538787841797 instead
# Expected wealthpooled=-0.3726208209991455, but found wealthpooled=1.9097405672073364 instead
# Expected households=21, but found households=23.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-1.1389659643173218, but found lat=-1.2842650413513184 instead
# Expected lon=36.75346755981445, but found lon=36.886566162109375 instead
# Expected wealthpooled=0.5871864557266235, but found wealthpooled=1.4598958492279053 instead
# Expected households=25, but found households=19.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-1.2214349508285522, but found lat=-1.2840720415115356 instead
# Expected lon=36.7347297668457, but found lon=36.908843994140625 instead
# Expected wealthpooled=0.719716489315033, but found wealthpooled=0.7588577270507812 instead
# Expected households=21, but found households=22.0 instead
# Expected lat=-1.0168609619140625, but found lat=-1.3037819862365723 instead
# Expected lon=36.72630310058594, but found lon=36.87472915649414 instead
# Expected wealthpooled=0.7629091143608093, but found wealthpooled=1.2578966617584229 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-1.0400389432907104, but found lat=-1.2961779832839966 instead
# Expected lon=37.07392120361328, but found lon=36.86812210083008 instead
# Expected wealthpooled=1.5013744831085205, but found wealthpooled=1.5289226770401 instead
# Expected households=20, but found households=22.0 instead
# Expected lat=-1.1477090120315552, but found lat=-1.3273530006408691 instead
# Expected lon=36.92987823486328, but found lon=36.8508415222168 instead
# Expected wealthpooled=0.8683792352676392, but found wealthpooled=0.7968233823776245 instead
# Expected households=21, but found households=24.0 instead
# Expected lat=-4.007012844085693, but found lat=-1.2836769819259644 instead
# Expected lon=39.708160400390625, but found lon=36.84230041503906 instead
# Expected wealthpooled=1.0045583248138428, but found wealthpooled=1.2538070678710938 instead
# Expected households=20, but found households=24.0 instead
# Expected lat=-4.008439064025879, but found lat=-1.3024389743804932 instead
# Expected lon=39.689613342285156, but found lon=36.883811950683594 instead
# Expected wealthpooled=1.088027000427246, but found wealthpooled=0.08290848135948181 instead
# Expected households=24, but found households=21.0 instead
# Expected lat=-4.033114910125732, but found lat=-1.3166919946670532 instead
# Expected lon=39.679256439208984, but found lon=36.872962951660156 instead
# Expected wealthpooled=1.3541789054870605, but found wealthpooled=0.9640756249427795 instead
# Expected households=22, but found households=23.0 instead
# Expected lat=-4.041944980621338, but found lat=-1.2601820230484009 instead
# Expected lon=39.623504638671875, but found lon=36.87736129760742 instead
# Expected wealthpooled=0.6341283917427063, but found wealthpooled=1.3871005773544312 instead
# Expected households=23, but found households=22.0 instead
# Expected lat=-4.014040946960449, but found lat=-1.2682470083236694 instead
# Expected lon=39.61811447143555, but found lon=36.825233459472656 instead
# Expected wealthpooled=0.4060707688331604, but found wealthpooled=2.260730266571045 instead
# Expected households=21, but found households=23.0 instead
# Expected lat=-4.09966516494751, but found lat=-1.2620550394058228 instead
# Expected lon=39.653358459472656, but found lon=36.8341064453125 instead
# Expected wealthpooled=1.1155767440795898, but found wealthpooled=0.4938808083534241 instead
# Expected households=20, but found households=24.0 instead
# Expected lat=-4.193787097930908, but found lat=-1.2636059522628784 instead
# Expected lon=39.55984878540039, but found lon=36.85056686401367 instead
# Expected wealthpooled=0.02836293913424015, but found wealthpooled=1.1724445819854736 instead
# Expected households=22, but found households=24.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-3.973083019256592, but found lat=-1.1952669620513916 instead
# Expected lon=39.24384689331055, but found lon=36.894989013671875 instead
# Expected wealthpooled=-0.7207813262939453, but found wealthpooled=1.2394434213638306 instead
# Expected households=25, but found households=23.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-4.284317970275879, but found lat=-1.2080719470977783 instead
# Expected lon=39.574520111083984, but found lon=36.89868927001953 instead
# Expected wealthpooled=0.510806143283844, but found wealthpooled=1.5265240669250488 instead
# Expected households=20, but found households=24.0 instead
# Expected lat=-4.367214202880859, but found lat=-1.1892529726028442 instead
# Expected lon=39.03675079345703, but found lon=36.905784606933594 instead
# Expected wealthpooled=-0.8733937740325928, but found wealthpooled=1.0994489192962646 instead
# Expected households=22, but found households=21.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-3.6254820823669434, but found lat=-1.2566219568252563 instead
# Expected lon=39.851016998291016, but found lon=36.878719329833984 instead
# Expected wealthpooled=0.5262404680252075, but found wealthpooled=1.3639564514160156 instead
# Expected households=23, but found households=21.0 instead
# Expected lat=-3.4900479316711426, but found lat=-1.2284120321273804 instead
# Expected lon=39.73748779296875, but found lon=36.936561584472656 instead
# Expected wealthpooled=-0.1634310930967331, but found wealthpooled=1.4117428064346313 instead
# Expected households=22, but found households=20.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-3.88460111618042, but found lat=-1.2302050590515137 instead
# Expected lon=39.52486038208008, but found lon=36.92454147338867 instead
# Expected wealthpooled=-0.4295951724052429, but found wealthpooled=1.7468663454055786 instead
# Expected households=25, but found households=21.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-3.2237629890441895, but found lat=-1.2403039932250977 instead
# Expected lon=40.116477966308594, but found lon=36.836997985839844 instead
# Expected wealthpooled=0.965316116809845, but found wealthpooled=2.629686117172241 instead
# Expected households=25, but found households=24.0 instead
# Expected lat=-3.1058480739593506, but found lat=-1.2588050365447998 instead
# Expected lon=39.78554916381836, but found lon=36.88184356689453 instead
# Expected wealthpooled=-0.3509998023509979, but found wealthpooled=1.2914183139801025 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-1.0516639947891235, but found lat=-1.2461199760437012 instead
# Expected lon=39.7330207824707, but found lon=36.8767204284668 instead
# Expected wealthpooled=-0.9106881618499756, but found wealthpooled=1.199471354484558 instead
# Expected households=21, but found households=22.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-1.5461269617080688, but found lat=-1.2710609436035156 instead
# Expected lon=39.21632385253906, but found lon=36.85728073120117 instead
# Expected wealthpooled=-0.6905860900878906, but found wealthpooled=0.8291522860527039 instead
# Expected households=23, but found households=24.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.4269619882106781, but found lat=-1.2816369533538818 instead
# Expected lon=39.40021514892578, but found lon=36.839683532714844 instead
# Expected wealthpooled=-0.8380653262138367, but found wealthpooled=1.6262279748916626 instead
# Expected households=25, but found households=21.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-1.9374710321426392, but found lat=-1.2767250537872314 instead
# Expected lon=39.96244812011719, but found lon=36.865135192871094 instead
# Expected wealthpooled=-0.6013632416725159, but found wealthpooled=0.5304895639419556 instead
# Expected households=25, but found households=24.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-2.25449800491333, but found lat=-1.2212469577789307 instead
# Expected lon=40.89137649536133, but found lon=36.8213996887207 instead
# Expected wealthpooled=0.6014308929443359, but found wealthpooled=0.9871729016304016 instead
# Expected households=20, but found households=23.0 instead
# Expected lat=-2.2814130783081055, but found lat=-1.2613279819488525 instead
# Expected lon=40.896915435791016, but found lon=36.75200653076172 instead
# Expected wealthpooled=0.3369019031524658, but found wealthpooled=1.115096092224121 instead
# Expected households=22, but found households=24.0 instead
# Expected lat=-2.228303909301758, but found lat=-1.2627209424972534 instead
# Expected lon=40.85572052001953, but found lon=36.80139923095703 instead
# Expected wealthpooled=0.15950517356395721, but found wealthpooled=2.2479119300842285 instead
# Expected households=19, but found households=21.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-2.4263288974761963, but found lat=-1.2829409837722778 instead
# Expected lon=40.72547149658203, but found lon=36.81635284423828 instead
# Expected wealthpooled=-0.25757142901420593, but found wealthpooled=1.6946938037872314 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-2.1076691150665283, but found lat=-0.19877000153064728 instead
# Expected lon=41.0268669128418, but found lon=36.52479553222656 instead
# Expected wealthpooled=-0.2689099609851837, but found wealthpooled=-0.07561872154474258 instead
# Expected households=24, but found households=23.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-3.4000051021575928, but found lat=-0.11072800308465958 instead
# Expected lon=38.5664176940918, but found lon=36.54856491088867 instead
# Expected wealthpooled=0.6326280832290649, but found wealthpooled=-0.2391340136528015 instead
# Expected households=21, but found households=25.0 instead
# Expected lat=-3.4799439907073975, but found lat=-0.023569000884890556 instead
# Expected lon=38.41551971435547, but found lon=36.4730224609375 instead
# Expected wealthpooled=0.008181477896869183, but found wealthpooled=-0.19090989232063293 instead
# Expected households=21, but found households=24.0 instead
# Expected lat=-3.2808239459991455, but found lat=0.029704999178647995 instead
# Expected lon=38.26645278930664, but found lon=36.41603469848633 instead
# Expected wealthpooled=-0.275469034910202, but found wealthpooled=0.8617492318153381 instead
# Expected households=24, but found households=21.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-3.0298659801483154, but found lat=-0.04831299930810928 instead
# Expected lon=38.640846252441406, but found lon=36.47953796386719 instead
# Expected wealthpooled=0.7343146800994873, but found wealthpooled=-0.2433207482099533 instead
# Expected lat=2.329184055328369, but found lat=-0.14893999695777893 instead
# Expected lon=37.943389892578125, but found lon=36.32431411743164 instead
# Expected wealthpooled=0.8676369786262512, but found wealthpooled=-0.07066347450017929 instead
# Expected households=23, but found households=22.0 instead
# Expected lat=4.111863136291504, but found lat=-0.02101000025868416 instead
# Expected lon=37.28504180908203, but found lon=36.327083587646484 instead
# Expected wealthpooled=-0.8260579109191895, but found wealthpooled=0.05107909068465233 instead
# Expected households=23, but found households=25.0 instead
# Expected lat=1.5924030542373657, but found lat=-0.14981800317764282 instead
# Expected lon=37.83837127685547, but found lon=36.37073516845703 instead
# Expected wealthpooled=-0.9340113401412964, but found wealthpooled=-0.11101780831813812 instead
# Expected households=23, but found households=21.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=3.516632080078125, but found lat=0.010666999965906143 instead
# Expected lon=39.0718994140625, but found lon=36.37981033325195 instead
# Expected wealthpooled=1.0446865558624268, but found wealthpooled=0.3719242513179779 instead
# Expected households=21, but found households=24.0 instead
# Expected lat=3.558458089828491, but found lat=-0.010617000050842762 instead
# Expected lon=38.64336013793945, but found lon=36.33293914794922 instead
# Expected wealthpooled=-0.1938607394695282, but found wealthpooled=0.5105894804000854 instead
# Expected households=21, but found households=19.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=0.33693599700927734, but found lat=0.009343000128865242 instead
# Expected lon=37.57037353515625, but found lon=36.37594985961914 instead
# Expected wealthpooled=1.205652117729187, but found wealthpooled=0.6391667723655701 instead
# Expected households=22, but found households=24.0 instead
# Expected lat=0.369159996509552, but found lat=-0.2756919860839844 instead
# Expected lon=37.59514236450195, but found lon=36.28675079345703 instead
# Expected wealthpooled=1.1419097185134888, but found wealthpooled=-0.10055837780237198 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=1.0098199844360352, but found lat=-0.18317900598049164 instead
# Expected lon=38.616363525390625, but found lon=36.25717544555664 instead
# Expected wealthpooled=-0.55954909324646, but found wealthpooled=-0.14573432505130768 instead
# Expected households=24, but found households=23.0 instead
# Expected lat=0.30521199107170105, but found lat=-0.20336399972438812 instead
# Expected lon=38.228153228759766, but found lon=36.28209686279297 instead
# Expected wealthpooled=0.16508141160011292, but found wealthpooled=0.2767883241176605 instead
# Expected households=23, but found households=24.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-0.00636899983510375, but found lat=-0.33160901069641113 instead
# Expected lon=37.69461441040039, but found lon=36.381187438964844 instead
# Expected wealthpooled=0.16041339933872223, but found wealthpooled=0.10031423717737198 instead
# Expected households=22, but found households=21.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=0.023902999237179756, but found lat=-0.3418720066547394 instead
# Expected lon=37.776947021484375, but found lon=36.3740348815918 instead
# Expected wealthpooled=0.2158018946647644, but found wealthpooled=-0.0968293771147728 instead
# Expected households=22, but found households=24.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.10210199654102325, but found lat=-0.2301419973373413 instead
# Expected lon=37.79108428955078, but found lon=36.386268615722656 instead
# Expected wealthpooled=0.9730700850486755, but found wealthpooled=0.09065840393304825 instead
# Expected lat=0.3288240134716034, but found lat=-0.23106999695301056 instead
# Expected lon=37.965919494628906, but found lon=36.323970794677734 instead
# Expected wealthpooled=-0.5922064185142517, but found wealthpooled=-0.22705216705799103 instead
# Expected households=25, but found households=23.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=0.21187900006771088, but found lat=-0.3181590139865875 instead
# Expected lon=38.05255889892578, but found lon=36.36000442504883 instead
# Expected wealthpooled=-0.6860719919204712, but found wealthpooled=-0.033337920904159546 instead
# Expected households=20, but found households=23.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.32921499013900757, but found lat=-0.39556801319122314 instead
# Expected lon=37.630916595458984, but found lon=36.53864669799805 instead
# Expected wealthpooled=0.8669095039367676, but found wealthpooled=-0.27204784750938416 instead
# Expected households=19, but found households=23.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-0.34333398938179016, but found lat=-0.3767310082912445 instead
# Expected lon=37.69932556152344, but found lon=36.540916442871094 instead
# Expected wealthpooled=-0.4101596176624298, but found wealthpooled=-0.1454673707485199 instead
# Expected households=22, but found households=21.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-0.31776800751686096, but found lat=-0.4046359956264496 instead
# Expected lon=37.718299865722656, but found lon=36.51725769042969 instead
# Expected wealthpooled=-0.5610432624816895, but found wealthpooled=0.7118707299232483 instead
# Expected households=23, but found households=21.0 instead
# Expected lat=-0.29045000672340393, but found lat=-0.41455399990081787 instead
# Expected lon=37.7226676940918, but found lon=36.4283332824707 instead
# Expected wealthpooled=-0.09881923347711563, but found wealthpooled=0.007576132658869028 instead
# Expected households=24, but found households=23.0 instead
# Expected lat=0.021916000172495842, but found lat=-0.6127099990844727 instead
# Expected lon=38.04643630981445, but found lon=36.46508026123047 instead
# Expected wealthpooled=-0.5290536284446716, but found wealthpooled=-0.0431256964802742 instead
# Expected households=22, but found households=25.0 instead
# Expected lat=-0.5442590117454529, but found lat=-0.6091920137405396 instead
# Expected lon=37.449073791503906, but found lon=36.59257888793945 instead
# Expected wealthpooled=1.3390763998031616, but found wealthpooled=1.1875593662261963 instead
# Expected households=23, but found households=21.0 instead
# Expected lat=-0.4774619936943054, but found lat=-0.570946991443634 instead
# Expected lon=37.44856643676758, but found lon=36.57275390625 instead
# Expected wealthpooled=0.18332457542419434, but found wealthpooled=0.14348289370536804 instead
# Expected households=24, but found households=25.0 instead
# Expected lat=-0.43243399262428284, but found lat=-0.5157830119132996 instead
# Expected lon=37.573394775390625, but found lon=36.6126594543457 instead
# Expected wealthpooled=1.3720192909240723, but found wealthpooled=0.13041812181472778 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-0.5918279886245728, but found lat=-0.7122859954833984 instead
# Expected lon=37.58373260498047, but found lon=36.663814544677734 instead
# Expected wealthpooled=0.10651454329490662, but found wealthpooled=0.7718318104743958 instead
# Expected households=24, but found households=21.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.7076650261878967, but found lat=-0.7397980093955994 instead
# Expected lon=37.718841552734375, but found lon=36.702415466308594 instead
# Expected wealthpooled=-0.5124989151954651, but found wealthpooled=0.12147808820009232 instead
# Expected households=24, but found households=21.0 instead
# Expected lat=-1.328029990196228, but found lat=-0.8814190030097961 instead
# Expected lon=37.97068405151367, but found lon=36.56947326660156 instead
# Expected wealthpooled=0.1559194028377533, but found wealthpooled=0.8395513296127319 instead
# Expected households=25, but found households=20.0 instead
# Expected lat=-1.534991979598999, but found lat=-0.8038949966430664 instead
# Expected lon=38.09247970581055, but found lon=36.598453521728516 instead
# Expected wealthpooled=-0.28813138604164124, but found wealthpooled=-0.06658491492271423 instead
# Expected households=24, but found households=21.0 instead
# Expected lat=-2.006364107131958, but found lat=-0.7619749903678894 instead
# Expected lon=38.42763137817383, but found lon=36.68714904785156 instead
# Expected wealthpooled=-0.4630264937877655, but found wealthpooled=-0.12254666537046432 instead
# Expected households=24, but found households=25.0 instead
# Expected lat=-1.0928230285644531, but found lat=-0.7488679885864258 instead
# Expected lon=38.025978088378906, but found lon=36.603538513183594 instead
# Expected wealthpooled=0.2783936858177185, but found wealthpooled=0.12263508141040802 instead
# Expected households=25, but found households=20.0 instead
# Expected lat=-1.4545780420303345, but found lat=-0.17932400107383728 instead
# Expected lon=36.97303009033203, but found lon=37.02791213989258 instead
# Expected wealthpooled=0.3012089431285858, but found wealthpooled=1.4783295392990112 instead
# Expected households=18, but found households=25.0 instead
# Expected lat=-1.4725370407104492, but found lat=-0.15036800503730774 instead
# Expected lon=37.28632736206055, but found lon=37.05803680419922 instead
# Expected wealthpooled=0.2964165508747101, but found wealthpooled=0.5904622673988342 instead
# Expected households=23, but found households=24.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-1.6122009754180908, but found lat=-0.19652000069618225 instead
# Expected lon=37.370601654052734, but found lon=37.030086517333984 instead
# Expected wealthpooled=-0.3437851369380951, but found wealthpooled=0.5291434526443481 instead
# Expected households=25, but found households=24.0 instead
# Expected lat=-0.8950030207633972, but found lat=-0.26988399028778076 instead
# Expected lon=37.746192932128906, but found lon=37.01346969604492 instead
# Expected wealthpooled=0.04167952015995979, but found wealthpooled=-0.010387741960585117 instead
# Expected households=23, but found households=22.0 instead
# Expected lat=-1.3520950078964233, but found lat=-0.023725999519228935 instead
# Expected lon=37.66192626953125, but found lon=37.04960632324219 instead
# Expected wealthpooled=-0.12882548570632935, but found wealthpooled=0.4707869589328766 instead
# Expected households=25, but found households=22.0 instead
# Expected lat=-1.1398719549179077, but found lat=-0.00952600035816431 instead
# Expected lon=37.27396774291992, but found lon=37.063865661621094 instead
# Expected wealthpooled=-0.2594211995601654, but found wealthpooled=0.7834742665290833 instead
# Expected households=24, but found households=25.0 instead
# Expected lat=-1.7959829568862915, but found lat=-0.257845014333725 instead
# Expected lon=37.63329315185547, but found lon=36.752803802490234 instead
# Expected wealthpooled=0.8064735531806946, but found wealthpooled=0.03830622881650925 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-1.5296779870986938, but found lat=-0.3097659945487976 instead
# Expected lon=37.46379852294922, but found lon=36.78584289550781 instead
# Expected wealthpooled=-0.27035367488861084, but found wealthpooled=0.05458907037973404 instead
# Expected households=25, but found households=23.0 instead
# Expected lat=-2.586932897567749, but found lat=-0.20457099378108978 instead
# Expected lon=38.122886657714844, but found lon=36.71017837524414 instead
# Expected wealthpooled=-0.3043699264526367, but found wealthpooled=0.008701488375663757 instead
# Expected households=22, but found households=24.0 instead
# Expected lat=-1.9050099849700928, but found lat=-0.4954240024089813 instead
# Expected lon=37.35850143432617, but found lon=37.12839126586914 instead
# Expected wealthpooled=-0.050455573946237564, but found wealthpooled=1.6169800758361816 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.45823198556900024, but found lat=-0.4305889904499054 instead
# Expected lon=39.636497497558594, but found lon=37.14385986328125 instead
# Expected wealthpooled=1.2146395444869995, but found wealthpooled=0.09868164360523224 instead
# Expected households=20, but found households=22.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-0.4584589898586273, but found lat=-0.4400700032711029 instead
# Expected lon=39.64164733886719, but found lon=37.09267044067383 instead
# Expected wealthpooled=0.6669254899024963, but found wealthpooled=0.3661196529865265 instead
# Expected households=23, but found households=25.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=0.723550021648407, but found lat=-0.3875420093536377 instead
# Expected lon=39.189720153808594, but found lon=37.12407684326172 instead
# Expected wealthpooled=-0.4706399738788605, but found wealthpooled=0.6365563869476318 instead
# Expected households=19, but found households=24.0 instead
# Expected lat=-0.18535399436950684, but found lat=-0.5015339851379395 instead
# Expected lon=40.02220916748047, but found lon=37.10529327392578 instead
# Expected wealthpooled=-0.5692551732063293, but found wealthpooled=0.10548415780067444 instead
# Expected households=16, but found households=25.0 instead
# Expected lat=-1.642285943031311, but found lat=-0.48529601097106934 instead
# Expected lon=40.4226188659668, but found lon=37.130550384521484 instead
# Expected wealthpooled=-0.8067956566810608, but found wealthpooled=1.164199948310852 instead
# Expected households=9, but found households=25.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=3.2624659538269043, but found lat=-0.5238320231437683 instead
# Expected lon=39.34478759765625, but found lon=37.12818145751953 instead
# Expected wealthpooled=-0.9878618121147156, but found wealthpooled=0.3895246982574463 instead
# Expected households=16, but found households=25.0 instead
# Expected lat=1.7624770402908325, but found lat=-0.3940429985523224 instead
# Expected lon=40.031925201416016, but found lon=37.08991622924805 instead
# Expected wealthpooled=-0.48508530855178833, but found wealthpooled=0.1436939686536789 instead
# Expected households=20, but found households=25.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=1.7372039556503296, but found lat=-0.48871299624443054 instead
# Expected lon=40.0569953918457, but found lon=37.00611114501953 instead
# Expected wealthpooled=0.9609355926513672, but found wealthpooled=0.6038946509361267 instead
# Expected households=24, but found households=25.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=1.6382880210876465, but found lat=-0.5879639983177185 instead
# Expected lon=39.422847747802734, but found lon=36.937259674072266 instead
# Expected wealthpooled=-0.9255240559577942, but found wealthpooled=0.6378392577171326 instead
# Expected households=20, but found households=25.0 instead
# Expected lat=2.832750082015991, but found lat=-0.52920001745224 instead
# Expected lon=40.918399810791016, but found lon=36.946807861328125 instead
# Expected wealthpooled=-0.6655680537223816, but found wealthpooled=0.09650744497776031 instead
# Expected households=22, but found households=24.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=3.022550106048584, but found lat=-0.5654259920120239 instead
# Expected lon=40.44477081298828, but found lon=36.886207580566406 instead
# Expected wealthpooled=-0.7054192423820496, but found wealthpooled=0.6509215831756592 instead
# Expected households=20, but found households=24.0 instead
# Expected lat=3.9279210567474365, but found lat=-0.5182539820671082 instead
# Expected lon=41.590789794921875, but found lon=36.9132194519043 instead
# Expected wealthpooled=-0.5105958580970764, but found wealthpooled=0.47715407609939575 instead
# Expected households=23, but found households=24.0 instead
# Expected lat=3.8835079669952393, but found lat=-0.5623220205307007 instead
# Expected lon=40.166019439697266, but found lon=36.9825325012207 instead
# Expected wealthpooled=-0.8697567582130432, but found wealthpooled=-0.10843969136476517 instead
# Expected lat=0.1433659940958023, but found lat=-0.6360139846801758 instead
# Expected lon=34.29990768432617, but found lon=37.123260498046875 instead
# Expected wealthpooled=-0.43443432450294495, but found wealthpooled=-0.009335651993751526 instead
# Expected households=23, but found households=24.0 instead
# Expected lat=0.12398199737071991, but found lat=-0.5271199941635132 instead
# Expected lon=34.10068893432617, but found lon=37.00751495361328 instead
# Expected wealthpooled=0.11929785460233688, but found wealthpooled=0.21270592510700226 instead
# Expected households=23, but found households=25.0 instead
# Expected lat=0.24188299477100372, but found lat=-0.4744890034198761 instead
# Expected lon=34.3658447265625, but found lon=36.832313537597656 instead
# Expected wealthpooled=-0.19475026428699493, but found wealthpooled=-0.12779448926448822 instead
# Expected lat=-0.0944020003080368, but found lat=-0.46978598833084106 instead
# Expected lon=34.28345489501953, but found lon=37.05437469482422 instead
# Expected wealthpooled=0.5106291770935059, but found wealthpooled=1.0043432712554932 instead
# Expected households=23, but found households=25.0 instead
# Expected lat=-0.062453001737594604, but found lat=-0.44266000390052795 instead
# Expected lon=34.38104248046875, but found lon=36.92586135864258 instead
# Expected wealthpooled=0.22986742854118347, but found wealthpooled=0.42253196239471436 instead
# Expected households=17, but found households=25.0 instead
# Expected lat=-0.10039900243282318, but found lat=-0.4361799955368042 instead
# Expected lon=34.79411315917969, but found lon=36.954200744628906 instead
# Expected wealthpooled=1.1931265592575073, but found wealthpooled=1.3475518226623535 instead
# Expected households=23, but found households=25.0 instead
# Expected lat=-0.0808819979429245, but found lat=-0.4663409888744354 instead
# Expected lon=34.74528503417969, but found lon=36.959659576416016 instead
# Expected wealthpooled=0.2286427915096283, but found wealthpooled=0.5754066705703735 instead
# Expected households=20, but found households=25.0 instead
# Expected lat=-0.13336600363254547, but found lat=-0.4229600131511688 instead
# Expected lon=34.61701583862305, but found lon=36.97764587402344 instead
# Expected wealthpooled=0.3596634864807129, but found wealthpooled=1.380025029182434 instead
# Expected households=25, but found households=23.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.13239899277687073, but found lat=-0.4277780055999756 instead
# Expected lon=34.926822662353516, but found lon=36.95343780517578 instead
# Expected wealthpooled=-0.3915409445762634, but found wealthpooled=-0.046767160296440125 instead
# Expected households=23, but found households=24.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.36036598682403564, but found lat=-0.4262720048427582 instead
# Expected lon=34.93096160888672, but found lon=36.970947265625 instead
# Expected wealthpooled=-0.28046995401382446, but found wealthpooled=1.8367512226104736 instead
# Expected households=20, but found households=23.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-1.0946780443191528, but found lat=-0.4349150061607361 instead
# Expected lon=34.464599609375, but found lon=36.964839935302734 instead
# Expected wealthpooled=-0.03980744257569313, but found wealthpooled=0.9795020222663879 instead
# Expected households=24, but found households=25.0 instead
# Expected lat=-1.0529969930648804, but found lat=-0.4379020035266876 instead
# Expected lon=34.254425048828125, but found lon=36.959495544433594 instead
# Expected wealthpooled=-0.7105500102043152, but found wealthpooled=1.2250422239303589 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.7147120237350464, but found lat=-0.6847010254859924 instead
# Expected lon=34.63606262207031, but found lon=37.28683853149414 instead
# Expected wealthpooled=-0.18875634670257568, but found wealthpooled=0.02161136083304882 instead
# Expected households=24, but found households=25.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-0.844897985458374, but found lat=-0.6749709844589233 instead
# Expected lon=34.58056640625, but found lon=37.30778503417969 instead
# Expected wealthpooled=-0.1408545970916748, but found wealthpooled=0.06896039843559265 instead
# Expected households=23, but found households=25.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-1.2376389503479004, but found lat=-0.7288450002670288 instead
# Expected lon=34.58522033691406, but found lon=37.3552131652832 instead
# Expected wealthpooled=-0.6966344118118286, but found wealthpooled=-0.3396872878074646 instead
# Expected households=24, but found households=25.0 instead
# Expected lat=-0.5489130020141602, but found lat=-0.5874000191688538 instead
# Expected lon=34.44881057739258, but found lon=37.35523223876953 instead
# Expected wealthpooled=1.064134120941162, but found wealthpooled=-0.22010572254657745 instead
# Expected households=24, but found households=22.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-0.8072090148925781, but found lat=-0.6684949994087219 instead
# Expected lon=34.28772735595703, but found lon=37.33958053588867 instead
# Expected wealthpooled=-0.5451915860176086, but found wealthpooled=-0.1178770512342453 instead
# Expected households=22, but found households=25.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.5340539813041687, but found lat=-0.68367999792099 instead
# Expected lon=34.40211486816406, but found lon=37.342891693115234 instead
# Expected wealthpooled=-0.4217873215675354, but found wealthpooled=-0.535697877407074 instead
# Expected households=23, but found households=22.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.4141849875450134, but found lat=-0.679813027381897 instead
# Expected lon=34.59153366088867, but found lon=37.354888916015625 instead
# Expected wealthpooled=-0.293581485748291, but found wealthpooled=0.872103214263916 instead
# Expected households=21, but found households=20.0 instead
# Expected lat=-0.433881014585495, but found lat=-0.6846590042114258 instead
# Expected lon=34.72335433959961, but found lon=37.368221282958984 instead
# Expected wealthpooled=-0.6249160170555115, but found wealthpooled=0.9833070635795593 instead
# Expected households=24, but found households=25.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.686152994632721, but found lat=-0.6287069916725159 instead
# Expected lon=34.77263641357422, but found lon=37.41975402832031 instead
# Expected wealthpooled=0.8522014617919922, but found wealthpooled=-0.48903489112854004 instead
# Expected households=24, but found households=25.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-0.6536999940872192, but found lat=-0.6705340147018433 instead
# Expected lon=34.78951644897461, but found lon=37.42005920410156 instead
# Expected wealthpooled=-0.2736639976501465, but found wealthpooled=-0.4975834786891937 instead
# Expected households=24, but found households=21.0 instead
# Expected lat=-0.8070930242538452, but found lat=-0.6041370034217834 instead
# Expected lon=34.944244384765625, but found lon=37.37736892700195 instead
# Expected wealthpooled=0.3310481309890747, but found wealthpooled=-0.14451463520526886 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-0.9236339926719666, but found lat=-0.47321000695228577 instead
# Expected lon=34.791847229003906, but found lon=37.222938537597656 instead
# Expected wealthpooled=0.49768009781837463, but found wealthpooled=1.3680229187011719 instead
# Expected households=24, but found households=22.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.7992969751358032, but found lat=-0.43703898787498474 instead
# Expected lon=34.63335037231445, but found lon=37.21818161010742 instead
# Expected wealthpooled=-0.5498026609420776, but found wealthpooled=0.3283582627773285 instead
# Expected households=25, but found households=22.0 instead
# Expected lat=-0.7792360186576843, but found lat=-0.5212560296058655 instead
# Expected lon=34.95038986206055, but found lon=37.27360153198242 instead
# Expected wealthpooled=1.7506144046783447, but found wealthpooled=-0.024414949119091034 instead
# Expected households=19, but found households=23.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-0.5740739703178406, but found lat=-0.48392099142074585 instead
# Expected lon=34.94356155395508, but found lon=37.286373138427734 instead
# Expected wealthpooled=-0.3090296685695648, but found wealthpooled=0.163486510515213 instead
# Expected households=24, but found households=23.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.6332409977912903, but found lat=-0.487278014421463 instead
# Expected lon=35.053348541259766, but found lon=37.27072525024414 instead
# Expected wealthpooled=-0.23751361668109894, but found wealthpooled=1.4747841358184814 instead
# Expected households=24, but found households=18.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.6150239706039429, but found lat=-0.5098299980163574 instead
# Expected lon=34.90375518798828, but found lon=37.317291259765625 instead
# Expected wealthpooled=-0.23624847829341888, but found wealthpooled=0.7058649063110352 instead
# Expected households=19, but found households=21.0 instead
# Expected lat=-0.7519199848175049, but found lat=-0.4670169949531555 instead
# Expected lon=35.02207946777344, but found lon=37.24955749511719 instead
# Expected wealthpooled=0.4168441593647003, but found wealthpooled=0.743650496006012 instead
# Expected households=21, but found households=24.0 instead
# Expected lat=3.1298420429229736, but found lat=-0.5242279767990112 instead
# Expected lon=35.73478698730469, but found lon=37.26111602783203 instead
# Expected wealthpooled=-1.0340356826782227, but found wealthpooled=0.2379097193479538 instead
# Expected households=25, but found households=21.0 instead
# Expected lat=3.320349931716919, but found lat=-0.4483020007610321 instead
# Expected lon=35.191932678222656, but found lon=37.314849853515625 instead
# Expected wealthpooled=-1.1775150299072266, but found wealthpooled=0.4815813899040222 instead
# Expected households=23, but found households=24.0 instead
# Expected lat=3.73881196975708, but found lat=-0.513463020324707 instead
# Expected lon=34.83924102783203, but found lon=37.239898681640625 instead
# Expected wealthpooled=-0.16842827200889587, but found wealthpooled=0.07409867644309998 instead
# Expected households=23, but found households=25.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=2.1952590942382812, but found lat=-0.4545550048351288 instead
# Expected lon=36.163665771484375, but found lon=37.17757797241211 instead
# Expected wealthpooled=-1.1156842708587646, but found wealthpooled=0.7690716981887817 instead
# Expected households=23, but found households=22.0 instead
# Expected lat=1.2398500442504883, but found lat=-0.5986199975013733 instead
# Expected lon=35.11850357055664, but found lon=37.26237869262695 instead
# Expected wealthpooled=0.043974097818136215, but found wealthpooled=0.03723864257335663 instead
# Expected households=22, but found households=21.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=1.18362295627594, but found lat=-0.5748609900474548 instead
# Expected lon=35.08207702636719, but found lon=37.26616668701172 instead
# Expected wealthpooled=-0.12946198880672455, but found wealthpooled=0.9769809246063232 instead
# Expected households=23, but found households=21.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=1.347687005996704, but found lat=-0.6419810056686401 instead
# Expected lon=35.19028854370117, but found lon=37.21268081665039 instead
# Expected wealthpooled=-0.5446577072143555, but found wealthpooled=0.07525989413261414 instead
# Expected lat=1.3885890245437622, but found lat=-0.6819419860839844 instead
# Expected lon=35.438194274902344, but found lon=37.21358871459961 instead
# Expected wealthpooled=-0.5106680989265442, but found wealthpooled=1.4567394256591797 instead
# Expected households=24, but found households=23.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=1.4046989679336548, but found lat=-0.5150169730186462 instead
# ...
# Expected wealthpooled=-0.6820253729820251, but found wealthpooled=-0.3726208209991455 instead
# Expected households=23, but found households=21.0 instead
# Expected lat=-0.6778330206871033, but found lat=-0.9328830242156982 instead
# Expected lon=35.90122604370117, but found lon=36.955665588378906 instead
# Expected wealthpooled=-0.18294137716293335, but found wealthpooled=0.8985825181007385 instead
# Expected households=22, but found households=21.0 instead
# Expected lat=-0.9228500127792358, but found lat=-0.9631310105323792 instead
# Expected lon=35.4354133605957, but found lon=37.034263610839844 instead
# Expected wealthpooled=-0.3850341737270355, but found wealthpooled=0.5811986327171326 instead
# Expected households=22, but found households=25.0 instead
# Expected lat=-0.9958739876747131, but found lat=-0.8754510283470154 instead
# Expected lon=35.148223876953125, but found lon=36.88438034057617 instead
# Expected wealthpooled=-0.10326152294874191, but found wealthpooled=0.6907030940055847 instead
# Expected households=22, but found households=25.0 instead
# Expected lat=-1.8459199666976929, but found lat=-1.216120958328247 instead
# Expected lon=36.78274917602539, but found lon=36.77058410644531 instead
# Expected wealthpooled=1.2042468786239624, but found wealthpooled=1.2040152549743652 instead
# Expected lat=-2.8302550315856934, but found lat=-1.1918209791183472 instead
# Expected lon=37.54056930541992, but found lon=36.78066635131836 instead
# Expected wealthpooled=-0.47781866788864136, but found wealthpooled=0.7927022576332092 instead
# Expected households=21, but found households=20.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-1.476781964302063, but found lat=-1.1987910270690918 instead
# Expected lon=36.965545654296875, but found lon=36.75389862060547 instead
# Expected wealthpooled=1.2663605213165283, but found wealthpooled=1.1573028564453125 instead
# Expected households=23, but found households=14.0 instead
# Expected lat=-1.3775570392608643, but found lat=-1.1389659643173218 instead
# Expected lon=36.63646697998047, but found lon=36.75346755981445 instead
# Expected wealthpooled=0.537583589553833, but found wealthpooled=0.5871864557266235 instead
# Expected households=20, but found households=25.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-1.3685929775238037, but found lat=-1.2077499628067017 instead
# Expected lon=36.655059814453125, but found lon=36.841392517089844 instead
# Expected wealthpooled=1.3636046648025513, but found wealthpooled=0.8728469610214233 instead
# Expected households=23, but found households=21.0 instead
# Expected lat=-0.24596400558948517, but found lat=-1.266975998878479 instead
# Expected lon=35.22739791870117, but found lon=36.6004524230957 instead
# Expected wealthpooled=-0.31101951003074646, but found wealthpooled=0.1732129156589508 instead
# Expected households=22, but found households=25.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.3836610019207001, but found lat=-1.2108490467071533 instead
# Expected lon=35.29874038696289, but found lon=36.656890869140625 instead
# Expected wealthpooled=1.2882217168807983, but found wealthpooled=1.4112523794174194 instead
# Expected households=19, but found households=20.0 instead
# Expected lat=-0.17465099692344666, but found lat=-1.2678600549697876 instead
# Expected lon=35.3109245300293, but found lon=36.67327117919922 instead
# Expected wealthpooled=-0.6117680072784424, but found wealthpooled=1.819358229637146 instead
# Expected households=24, but found households=23.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.2887449860572815, but found lat=-1.2509870529174805 instead
# Expected lon=35.42853546142578, but found lon=36.71236038208008 instead
# Expected wealthpooled=-0.13244204223155975, but found wealthpooled=1.2739219665527344 instead
# Expected households=20, but found households=22.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.5060520172119141, but found lat=-1.2268790006637573 instead
# Expected lon=35.27607727050781, but found lon=36.70215606689453 instead
# Expected wealthpooled=0.2925487458705902, but found wealthpooled=0.8954240083694458 instead
# Expected households=22, but found households=20.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.8927969932556152, but found lat=-1.2214349508285522 instead
# Expected lon=35.03740310668945, but found lon=36.7347297668457 instead
# Expected wealthpooled=-0.40878769755363464, but found wealthpooled=0.719716489315033 instead
# Expected households=17, but found households=21.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.6907449960708618, but found lat=-1.1503340005874634 instead
# Expected lon=35.27423858642578, but found lon=36.59721374511719 instead
# Expected wealthpooled=-0.3987346589565277, but found wealthpooled=0.8231827020645142 instead
# Expected households=24, but found households=21.0 instead
# Expected lat=-0.7899540066719055, but found lat=-1.0769230127334595 instead
# Expected lon=35.338409423828125, but found lon=36.6264533996582 instead
# Expected wealthpooled=0.9839329719543457, but found wealthpooled=1.0893608331680298 instead
# Expected households=19, but found households=17.0 instead
# Expected lat=-1.003358006477356, but found lat=-1.0997899770736694 instead
# Expected lon=35.27610778808594, but found lon=36.6966552734375 instead
# Expected wealthpooled=-0.7041407227516174, but found wealthpooled=0.8638224601745605 instead
# Expected households=23, but found households=17.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=0.4342060089111328, but found lat=-0.876380980014801 instead
# Expected lon=34.681026458740234, but found lon=36.62350082397461 instead
# Expected wealthpooled=-0.45343539118766785, but found wealthpooled=0.08161371201276779 instead
# Expected households=22, but found households=21.0 instead
# Expected lat=0.19901500642299652, but found lat=-0.9337729811668396 instead
# Expected lon=34.77046203613281, but found lon=36.596336364746094 instead
# Expected wealthpooled=-0.31607556343078613, but found wealthpooled=1.2099034786224365 instead
# Expected households=25, but found households=19.0 instead
# Expected lat=0.5679849982261658, but found lat=-1.0067050457000732 instead
# Expected lon=34.78498458862305, but found lon=36.739990234375 instead
# Expected wealthpooled=-0.1886214017868042, but found wealthpooled=0.9992406368255615 instead
# Expected households=22, but found households=18.0 instead
# Expected lat=0.37583500146865845, but found lat=-1.0168609619140625 instead
# Expected lon=34.46717071533203, but found lon=36.72630310058594 instead
# Expected wealthpooled=-0.3703029751777649, but found wealthpooled=0.7629091143608093 instead
# Expected households=21, but found households=22.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=0.3196989893913269, but found lat=-1.1368989944458008 instead
# Expected lon=34.44491195678711, but found lon=36.768638610839844 instead
# Expected wealthpooled=-0.42868340015411377, but found wealthpooled=0.6877092719078064 instead
# Expected households=24, but found households=21.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=0.11484400182962418, but found lat=-1.0928889513015747 instead
# Expected lon=34.722816467285156, but found lon=36.79035186767578 instead
# Expected wealthpooled=-0.2578733563423157, but found wealthpooled=0.5269313454627991 instead
# Expected households=22, but found households=25.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=0.11049800366163254, but found lat=-1.0312550067901611 instead
# Expected lon=34.76728057861328, but found lon=36.84781265258789 instead
# Expected wealthpooled=-0.05261940136551857, but found wealthpooled=0.5093560814857483 instead
# Expected households=23, but found households=25.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=0.07828900218009949, but found lat=-1.0390299558639526 instead
# Expected lon=34.71085739135742, but found lon=37.261505126953125 instead
# Expected wealthpooled=0.007704499177634716, but found wealthpooled=-0.5333216786384583 instead
# Expected households=23, but found households=24.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=0.023384999483823776, but found lat=-1.0711560249328613 instead
# Expected lon=34.56349182128906, but found lon=37.012821197509766 instead
# Expected wealthpooled=-0.5442182421684265, but found wealthpooled=0.6623994708061218 instead
# Expected households=24, but found households=22.0 instead
# Expected lat=0.17049600183963776, but found lat=-1.039942979812622 instead
# Expected lon=34.81874465942383, but found lon=37.08675003051758 instead
# Expected wealthpooled=-0.5009486079216003, but found wealthpooled=0.8664737343788147 instead
# Expected households=24, but found households=20.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=0.5755490064620972, but found lat=-1.0400389432907104 instead
# Expected lon=34.51834487915039, but found lon=37.07392120361328 instead
# Expected wealthpooled=-0.4867287874221802, but found wealthpooled=1.5013744831085205 instead
# Expected households=24, but found households=20.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=0.591605007648468, but found lat=-1.0531280040740967 instead
# Expected lon=34.436439514160156, but found lon=37.08696746826172 instead
# Expected wealthpooled=-0.5920441746711731, but found wealthpooled=0.3693335950374603 instead
# Expected households=24, but found households=9.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=0.771926999092102, but found lat=-1.0751659870147705 instead
# Expected lon=34.71674346923828, but found lon=37.09354019165039 instead
# Expected wealthpooled=-0.06701690703630447, but found wealthpooled=0.9849115014076233 instead
# Expected lat=0.7020130157470703, but found lat=-1.202468991279602 instead
# Expected lon=34.648780822753906, but found lon=36.919464111328125 instead
# Expected wealthpooled=0.6333782076835632, but found wealthpooled=1.7793594598770142 instead
# Expected households=23, but found households=24.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=0.6629400253295898, but found lat=-1.1960200071334839 instead
# Expected lon=34.61598587036133, but found lon=36.94953155517578 instead
# Expected wealthpooled=-0.5812888145446777, but found wealthpooled=1.2143094539642334 instead
# Expected households=22, but found households=21.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=0.4461059868335724, but found lat=-1.211488962173462 instead
# Expected lon=34.126216888427734, but found lon=36.92461395263672 instead
# Expected wealthpooled=0.7691921591758728, but found wealthpooled=1.4988911151885986 instead
# Expected households=24, but found households=21.0 instead
# Expected lat=0.5414239764213562, but found lat=-1.1502280235290527 instead
# Expected lon=34.33420181274414, but found lon=37.017181396484375 instead
# Expected wealthpooled=-0.31105712056159973, but found wealthpooled=0.8038731217384338 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=0.6016510128974915, but found lat=-1.1477090120315552 instead
# Expected lon=34.226558685302734, but found lon=36.92987823486328 instead
# Expected wealthpooled=-0.7972830533981323, but found wealthpooled=0.8683792352676392 instead
# Expected households=22, but found households=21.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=0.09172900021076202, but found lat=-1.1642999649047852 instead
# Expected lon=33.97426986694336, but found lon=36.94150924682617 instead
# Expected wealthpooled=0.39527976512908936, but found wealthpooled=1.1045466661453247 instead
# Expected households=20, but found households=22.0 instead
# Expected lat=0.5009920001029968, but found lat=-0.9541299939155579 instead
# Expected lon=34.17488479614258, but found lon=36.827880859375 instead
# Expected wealthpooled=-0.5953638553619385, but found wealthpooled=0.11722969263792038 instead
# Expected households=24, but found households=23.0 instead
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\planet_project\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     350                 try:
# --> 351                     return self._range.index(new_key)
#     352                 except ValueError as err:
#
# ValueError: 1589 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-55760d641e80> in <module>
# ----> 1 crosscheck_records(csv_path='data/ke_dhs_surveys/kenya_2014.csv', tfrecord_path=TFRECORD_PATH_TEMPLATE.format(year=2014))
#
# <ipython-input-39-33b78e3801a3> in crosscheck_records(csv_path, tfrecord_path)
#      35             assert band in feature_map, f'Band "{band}" not in record {i} of {tfrecord_path}'
#      36
# ---> 37         csv_feats = df.loc[i, :].to_dict()
#      38         for col, val in csv_feats.items():
#      39             ft_type = feature_map[col].WhichOneof('kind')
#
# ~\anaconda3\envs\planet_project\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~\anaconda3\envs\planet_project\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1058     def _getitem_tuple(self, tup: Tuple):
#    1059         with suppress(IndexingError):
# -> 1060             return self._getitem_lowerdim(tup)
#    1061
#    1062         # no multi-index, so validate all of the indexers
#
# ~\anaconda3\envs\planet_project\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     805                 # We don't need to check for tuples here because those are
#     806                 #  caught by the _is_nested_tuple_indexer check above.
# --> 807                 section = self._getitem_axis(key, axis=i)
#     808
#     809                 # We should never have a scalar section here, because
#
# ~\anaconda3\envs\planet_project\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\envs\planet_project\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~\anaconda3\envs\planet_project\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3737                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3738         else:
# -> 3739             loc = index.get_loc(key)
#    3740
#    3741             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\envs\planet_project\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     351                     return self._range.index(new_key)
#     352                 except ValueError as err:
# --> 353                     raise KeyError(key) from err
#     354             raise KeyError(key)
#     355         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 1589

# %%
crosscheck_records(csv_path='data/ke_dhs_surveys/kenya_2015.csv', tfrecord_path=TFRECORD_PATH_TEMPLATE.format(year=2015))
# Out:
#   0%|          | 0/245 [00:00<?, ?it/s]
# Expected lat=-0.0021780000533908606, but found lat=-1.3389370441436768 instead
# Expected lon=36.364097595214844, but found lon=36.759521484375 instead
# Expected wealthpooled=0.9807378649711609, but found wealthpooled=1.2465413808822632 instead
# Expected households=25, but found households=17.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.5667009949684143, but found lat=-1.2705830335617065 instead
# Expected lon=37.04641342163086, but found lon=36.96373748779297 instead
# Expected wealthpooled=1.0735020637512207, but found wealthpooled=1.5495524406433105 instead
# Expected households=29, but found households=24.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.5231860280036926, but found lat=-1.3225150108337402 instead
# Expected lon=37.261741638183594, but found lon=36.90370178222656 instead
# Expected wealthpooled=1.2819308042526245, but found wealthpooled=1.7608996629714966 instead
# Expected households=30, but found households=25.0 instead
# Expected lat=-1.061885952949524, but found lat=-1.3183530569076538 instead
# Expected lon=36.6513557434082, but found lon=36.83525085449219 instead
# Expected wealthpooled=0.48833975195884705, but found wealthpooled=1.1905049085617065 instead
# Expected households=27, but found households=28.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-1.2127259969711304, but found lat=-1.2069200277328491 instead
# Expected lon=36.918758392333984, but found lon=36.88164520263672 instead
# Expected wealthpooled=1.2059626579284668, but found wealthpooled=1.7296074628829956 instead
# Expected lat=-4.354394912719727, but found lat=-1.2760189771652222 instead
# Expected lon=39.21718215942383, but found lon=36.858856201171875 instead
# Expected wealthpooled=-0.3617725372314453, but found wealthpooled=2.185293436050415 instead
# Expected households=25, but found households=28.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-4.292095184326172, but found lat=-0.0021780000533908606 instead
# Expected lon=39.54676055908203, but found lon=36.364097595214844 instead
# Expected wealthpooled=0.7214825749397278, but found wealthpooled=0.9807378649711609 instead
# Expected households=27, but found households=25.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-3.857072114944458, but found lat=-0.4270870089530945 instead
# Expected lon=39.47206497192383, but found lon=36.4476432800293 instead
# Expected wealthpooled=0.6926643252372742, but found wealthpooled=0.5962212085723877 instead
# Expected households=27, but found households=28.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-2.2299768924713135, but found lat=-0.7068639993667603 instead
# Expected lon=40.85441589355469, but found lon=36.58955001831055 instead
# Expected wealthpooled=0.21774397790431976, but found wealthpooled=-0.007766194641590118 instead
# Expected households=25, but found households=27.0 instead
# Expected lat=-3.3253979682922363, but found lat=-0.18650400638580322 instead
# Expected lon=38.37006759643555, but found lon=36.50619125366211 instead
# Expected wealthpooled=-0.07430105656385422, but found wealthpooled=-0.16969850659370422 instead
# Expected households=28, but found households=26.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=2.315242052078247, but found lat=-0.19483500719070435 instead
# Expected lon=37.98591232299805, but found lon=36.42721176147461 instead
# Expected wealthpooled=1.004256010055542, but found wealthpooled=-0.0731808990240097 instead
# Expected households=21, but found households=28.0 instead
# Expected lat=0.25054600834846497, but found lat=-0.17552700638771057 instead
# Expected lon=37.970985412597656, but found lon=36.8570556640625 instead
# Expected wealthpooled=0.24659143388271332, but found wealthpooled=-0.057129159569740295 instead
# Expected households=29, but found households=24.0 instead
# Expected lat=-0.37905699014663696, but found lat=-0.3858709931373596 instead
# Expected lon=37.47444534301758, but found lon=37.10973358154297 instead
# Expected wealthpooled=0.29970934987068176, but found wealthpooled=-0.061607152223587036 instead
# Expected households=30, but found households=29.0 instead
# Expected lat=-0.9465720057487488, but found lat=-0.5667009949684143 instead
# Expected lon=38.051116943359375, but found lon=37.04641342163086 instead
# Expected wealthpooled=0.5576841235160828, but found wealthpooled=1.0735020637512207 instead
# Expected households=26, but found households=29.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-1.6512809991836548, but found lat=-0.47656500339508057 instead
# Expected lon=37.572967529296875, but found lon=37.141746520996094 instead
# Expected wealthpooled=-0.4257626533508301, but found wealthpooled=1.1719255447387695 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.42569300532341003, but found lat=-0.42403700947761536 instead
# Expected lon=39.66776657104492, but found lon=36.936092376708984 instead
# Expected wealthpooled=0.9198731780052185, but found wealthpooled=1.5039771795272827 instead
# Expected lat=2.814652919769287, but found lat=-0.7481589913368225 instead
# Expected lon=40.93940734863281, but found lon=37.34099578857422 instead
# Expected wealthpooled=0.7947067618370056, but found wealthpooled=-0.24538975954055786 instead
# Expected households=20, but found households=30.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-0.1295669972896576, but found lat=-0.5223590135574341 instead
# Expected lon=34.25335693359375, but found lon=37.27340316772461 instead
# Expected wealthpooled=0.08349069207906723, but found wealthpooled=0.20501859486103058 instead
# Expected households=28, but found households=30.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-0.9539520144462585, but found lat=-0.5311980247497559 instead
# Expected lon=34.14848709106445, but found lon=37.38533020019531 instead
# Expected wealthpooled=-0.14929161965847015, but found wealthpooled=0.19664797186851501 instead
# Expected households=25, but found households=30.0 instead
# Expected lat=-0.4199250042438507, but found lat=-0.67290198802948 instead
# Expected lon=34.636085510253906, but found lon=37.35406494140625 instead
# Expected wealthpooled=-0.14710307121276855, but found wealthpooled=1.0934115648269653 instead
# Expected households=28, but found households=30.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=-0.6434860229492188, but found lat=-0.5231860280036926 instead
# Expected lon=34.75982666015625, but found lon=37.261741638183594 instead
# Expected wealthpooled=0.7546932697296143, but found wealthpooled=1.2819308042526245 instead
# Expected households=27, but found households=30.0 instead
# Expected lat=3.203882932662964, but found lat=-0.7125319838523865 instead
# Expected lon=35.245323181152344, but found lon=36.91559600830078 instead
# Expected wealthpooled=-0.8354724645614624, but found wealthpooled=0.004435957875102758 instead
# Expected households=20, but found households=29.0 instead
# Expected lat=1.2906759977340698, but found lat=-0.6065009832382202 instead
# Expected lon=35.17012023925781, but found lon=36.96476364135742 instead
# Expected wealthpooled=-0.507879376411438, but found wealthpooled=-0.01794043928384781 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=1.0173859596252441, but found lat=-0.9661149978637695 instead
# Expected lon=35.16860580444336, but found lon=37.150630950927734 instead
# Expected wealthpooled=-0.06212892755866051, but found wealthpooled=0.2321082055568695 instead
# Expected households=28, but found households=26.0 instead
# Expected lat=0.04686199873685837, but found lat=-1.0293660163879395 instead
# Expected lon=35.72775650024414, but found lon=37.15134811401367 instead
# Expected wealthpooled=0.7713978886604309, but found wealthpooled=0.6951912641525269 instead
# Expected households=25, but found households=26.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=0.9898959994316101, but found lat=-0.7166230082511902 instead
# Expected lon=35.45912170410156, but found lon=37.15740203857422 instead
# Expected wealthpooled=0.014563878998160362, but found wealthpooled=0.9328234791755676 instead
# Expected households=29, but found households=24.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=0.19295500218868256, but found lat=-0.899258017539978 instead
# Expected lon=35.07558059692383, but found lon=37.20903396606445 instead
# Expected wealthpooled=0.3301715552806854, but found wealthpooled=1.0255366563796997 instead
# Expected households=25, but found households=23.0 instead
# Expected lat=-0.0638590008020401, but found lat=-1.061885952949524 instead
# Expected lon=36.078407287597656, but found lon=36.6513557434082 instead
# Expected wealthpooled=-0.3810509145259857, but found wealthpooled=0.48833975195884705 instead
# Expected households=25, but found households=27.0 instead
# Expected lat=-0.741104006767273, but found lat=-1.0773639678955078 instead
# Expected lon=36.511444091796875, but found lon=36.98975372314453 instead
# Expected wealthpooled=0.3665660619735718, but found wealthpooled=0.534129798412323 instead
# Expected households=30, but found households=28.0 instead
# Expected urban_rural=1, but found urban_rural=0.0 instead
# Expected lat=-1.6821240186691284, but found lat=-0.8977220058441162 instead
# Expected lon=36.886085510253906, but found lon=36.79401397705078 instead
# Expected wealthpooled=0.5721684098243713, but found wealthpooled=0.22199968993663788 instead
# Expected households=30, but found households=28.0 instead
# Expected lat=-0.5248110294342041, but found lat=-1.1798889636993408 instead
# Expected lon=35.21303176879883, but found lon=36.72542953491211 instead
# Expected wealthpooled=-0.14479272067546844, but found wealthpooled=0.6615684032440186 instead
# Expected households=27, but found households=29.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=0.6196879744529724, but found lat=-1.1645150184631348 instead
# Expected lon=34.9339599609375, but found lon=36.641029357910156 instead
# Expected wealthpooled=-0.025817763060331345, but found wealthpooled=1.3938721418380737 instead
# Expected households=27, but found households=22.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=0.11717800050973892, but found lat=-1.2246650457382202 instead
# Expected lon=34.81974792480469, but found lon=36.709625244140625 instead
# Expected wealthpooled=-0.32888081669807434, but found wealthpooled=1.2646496295928955 instead
# Expected households=26, but found households=28.0 instead
# Expected urban_rural=0, but found urban_rural=1.0 instead
# Expected lat=0.829679012298584, but found lat=-1.0683870315551758 instead
# Expected lon=34.756160736083984, but found lon=37.104736328125 instead
# Expected wealthpooled=-0.6420150399208069, but found wealthpooled=1.381998896598816 instead
# Expected households=28, but found households=24.0 instead
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\planet_project\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     350                 try:
# --> 351                     return self._range.index(new_key)
#     352                 except ValueError as err:
#
# ValueError: 245 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-8ff214195d2c> in <module>
# ----> 1 crosscheck_records(csv_path='data/ke_dhs_surveys/kenya_2015.csv', tfrecord_path=TFRECORD_PATH_TEMPLATE.format(year=2015))
#
# <ipython-input-39-33b78e3801a3> in crosscheck_records(csv_path, tfrecord_path)
#      35             assert band in feature_map, f'Band "{band}" not in record {i} of {tfrecord_path}'
#      36
# ---> 37         csv_feats = df.loc[i, :].to_dict()
#      38         for col, val in csv_feats.items():
#      39             ft_type = feature_map[col].WhichOneof('kind')
#
# ~\anaconda3\envs\planet_project\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~\anaconda3\envs\planet_project\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1058     def _getitem_tuple(self, tup: Tuple):
#    1059         with suppress(IndexingError):
# -> 1060             return self._getitem_lowerdim(tup)
#    1061
#    1062         # no multi-index, so validate all of the indexers
#
# ~\anaconda3\envs\planet_project\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     805                 # We don't need to check for tuples here because those are
#     806                 #  caught by the _is_nested_tuple_indexer check above.
# --> 807                 section = self._getitem_axis(key, axis=i)
#     808
#     809                 # We should never have a scalar section here, because
#
# ~\anaconda3\envs\planet_project\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\envs\planet_project\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~\anaconda3\envs\planet_project\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3737                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3738         else:
# -> 3739             loc = index.get_loc(key)
#    3740
#    3741             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\envs\planet_project\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     351                     return self._range.index(new_key)
#     352                 except ValueError as err:
# --> 353                     raise KeyError(key) from err
#     354             raise KeyError(key)
#     355         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 245

# %% [markdown]
# # Splitting the TFRecord Files into Training, Validation and Testing Datasets

# %%
# Load in our dataset, shuffle the input features.
files = os.listdir(DHS_FOLDER) 
files = [f'{DHS_FOLDER}/{fn}' for fn in files] 
files
# Out:
# ['data/ke_dhs_tfrecords_raw/kenya_2014.tfrecord.gz',
#  'data/ke_dhs_tfrecords_raw/kenya_2015.tfrecord.gz']

# %%
# Getting the size/len of the records in each tfrecord files
options = tf.io.TFRecordOptions(compression_type = 'GZIP')

DATASET_SIZE = 0
for file in files:
    size = len([x for x in tf.compat.v1.io.tf_record_iterator(file, options=options)])
    
    DATASET_SIZE += size

DATASET_SIZE
# Out:
# 1830

# %%
# splitting the datasets into training, evaluating and testing sets
train_size = int(0.7 * DATASET_SIZE)
val_size = int(0.15 * DATASET_SIZE)
test_size = int(0.15 * DATASET_SIZE)

dataset = tf.data.TFRecordDataset(files, compression_type='GZIP')
dataset = dataset.shuffle(buffer_size=100)
trainset = dataset.take(train_size)
testset = dataset.skip(train_size)
valset = testset.skip(test_size)
testset = testset.take(test_size)

# %%
def write(dataset, outdir, outfile, compress=True):
    '''
    Writes the datasets into a TFrecord File
  
    Args: 
    dataset: Variable, dataset to write into tfrecord
    outdir: String, path in which to save the serialized dataset
    outfile: String, name in which to save the serialized tfrecord file
    compress: Boolean, whether or not to apply gzip compression
    Returns: None
    '''
    os.makedirs(outdir, exist_ok=True)
    outpath = os.path.join(outdir, outfile)

    if compress == True:
        writer = tf.data.experimental.TFRecordWriter(outpath, compression_type='GZIP')
        writer.write(dataset)
        
    else:
        writer = tf.data.experimental.TFRecordWriter(outpath)
        writer.write(dataset)

# %%
outdir = 'data/datasets'

write(dataset=trainset, outdir=outdir, outfile='trainset.tfrecord.gz', compress=True)
write(dataset=valset, outdir=outdir, outfile='valset.tfrecord.gz', compress=True)
write(dataset=testset, outdir=outdir, outfile='testset.tfrecord.gz', compress=True)

# %%
feature_types = get_feature_types('data/datasets/valset.tfrecord.gz')
print('Features and types:')
pprint(feature_types)
